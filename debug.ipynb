# %%
import os
import glob
import pandas as pd

# %%
list = glob.glob("NSE LargeMidcap 250 Historical data/nifty_largemidcap_250_*.csv")[::-1]

# %%
for i in list:
    df = pd.read_csv(i)
    # if df.__len__() == 250:
    #     continue
    
    print(f"Date: {i.split('_')[-1].split('.')[0]}, Length: {df.__len__()}")
    # print(df.__len__())
# Out:
# Date: 2026-07-13, Length: 250
# Date: 2026-07-10, Length: 250
# Date: 2026-07-08, Length: 250
# Date: 2026-02-23, Length: 250
# Date: 2025-08-22, Length: 250
# Date: 2025-02-21, Length: 250
# Date: 2024-08-23, Length: 251
# Date: 2024-02-28, Length: 251
# Date: 2023-08-17, Length: 250
# Date: 2023-07-04, Length: 250
# Date: 2023-02-17, Length: 250
# Date: 2022-09-01, Length: 250
# Date: 2022-07-11, Length: 250
# Date: 2022-04-05, Length: 250
# Date: 2022-02-24, Length: 250
# Date: 2021-10-22, Length: 250
# Date: 2021-08-23, Length: 250
# Date: 2021-06-15, Length: 250
# Date: 2021-02-23, Length: 250
# Date: 2020-08-20, Length: 250
# Date: 2020-07-02, Length: 250
# Date: 2020-06-10, Length: 251
# Date: 2020-03-19, Length: 251
# Date: 2019-12-27, Length: 251
# Date: 2019-09-27, Length: 251
# Date: 2019-06-28, Length: 251
# Date: 2019-03-29, Length: 251
# Date: 2018-12-28, Length: 251
# Date: 2018-09-28, Length: 251
# Date: 2018-06-29, Length: 251
# Date: 2018-04-02, Length: 251
# ...
